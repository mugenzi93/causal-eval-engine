# %% [markdown]
# ---
# title: "Example R Notebook"
# author: "Clement Mugenzi"
# date: "2024-05-28"
# engine: jupyter
# jupyter:
#   kernel: ir
# ---

# %%
install.packages("tidyverse")
# Out:
# also installing the dependencies 'systemfonts', 'progress', 'gtable', 'S7', 'scales', 'timechange', 'textshaping', 'vroom', 'cpp11', 'conflicted', 'ggplot2', 'lubridate', 'ragg', 'readr', 'readxl'
#   There are binary versions available but the source versions are later:
#             binary source needs_compilation
# systemfonts  1.1.0  1.3.2              TRUE
# gtable       0.3.5  0.3.6             FALSE
# S7           0.1.1  0.2.2              TRUE
# scales       1.3.0  1.4.0             FALSE
# timechange   0.3.0  0.4.0              TRUE
# textshaping  0.4.0  1.0.5              TRUE
# vroom        1.6.5  1.7.1              TRUE
# cpp11        0.4.7  0.5.5             FALSE
# ggplot2      3.5.1  4.0.3             FALSE
# lubridate    1.9.3  1.9.5              TRUE
# ragg         1.3.2  1.5.2              TRUE
# readr        2.1.5  2.2.0              TRUE
# readxl       1.4.3  1.5.0              TRUE
#
#
# The downloaded binary packages are in
# ...

# %%
# checking installed packages and their versions
pkgs <- installed.packages()[, c("Package", "Version")]
cat(paste(pkgs[,1], pkgs[,2], sep="=="), sep="\n")
# Out:
# CRTgeeDR==2.0.1
# DBI==1.1.3
# Deriv==4.1.3
# FSA==0.9.5
# Formula==1.2-4
# Hotelling==1.0-8
# IRdisplay==1.1
# IRkernel==1.3.2
# ISLR==1.4
# KernSmooth==2.23-20
# MASS==7.3-58.1
# Matrix==1.5-1
# ModelMetrics==1.2.2.2
# R6==2.6.1
# RANN==2.6.1
# RColorBrewer==1.1-3
# Rcpp==1.0.10
# RcppArmadillo==0.11.4.3.1
# RcppEigen==0.3.3.9.3
# RcppProgress==0.4.2
# Rdpack==2.5
# S7==0.2.2
# SQUAREM==2021.1
# SparseM==1.81
# TH.data==1.1-1
# TeachingDemos==2.12
# V8==4.4.0
# VGAM==1.1-7
# abind==1.4-5
# alluvial==0.1-2
# alphashape3d==1.3.2
# arsenal==3.6.3
# askpass==1.1
# assertthat==0.2.1
# backports==1.4.1
# base==4.2.2
# base64enc==0.1-3
# bit==4.0.5
# bit64==4.0.5
# blob==1.2.3
# boot==1.3-28
# brew==1.0-10
# brio==1.1.5
# broom==1.0.3
# bslib==0.11.0
# cachem==1.0.6
# callr==3.7.6
# car==3.1-2
# carData==3.0-5
# caret==6.0-93
# cellranger==1.1.0
# class==7.3-20
# cli==3.6.6
# clipr==0.8.0
# clock==0.6.1
# cluster==2.1.4
# codetools==0.2-18
# coin==1.4-2
# colorspace==2.1-0
# ...
